# %%
import acquisition
import hardware
from importlib import reload
import matplotlib.pyplot as plt
import time
import numpy as np

# %% [markdown]
# ### Run this cell to reload the imports after making changes to the code

# %%
reload(hardware)
reload(acquisition)

print(f"Modules reloaded at {time.strftime('%H:%M:%S')}")
# Out:
# Modules reloaded at 11:29:12

# %% [markdown]
# ### Get the counts and timestamps from the APD
#
# Save the counts and timestamps in two variables named `counts` and `timestamps` respectively.

# %%
# Your code here

apd = hardware.APD()
apd.connect()
counts, timestamps = acquisition.get_data_vs_time(apd, 12)

print(counts)
print(timestamps)
# Out:
# [1045, 989, 1007, 997, 980, 902, 1033, 958, 1026, 1011, 930, 1004, 1001, 1029, 994, 1035, 992, 964, 1004, 1015, 1005, 993, 987, 925, 1038, 998, 999, 966, 991, 1012, 988, 1000, 1015, 941, 1064, 990, 996, 1065, 969, 952, 950, 942, 1037, 1032, 956, 1012, 1022, 979, 1024, 988, 985, 1039, 1024, 953, 1000, 983, 990, 1049, 983, 1072, 1012, 980, 1016, 1029, 949, 934, 995, 986, 961, 1011, 947, 942, 1019, 988, 989, 1027, 993, 955, 933, 956, 1024, 1085, 980, 943, 1012, 996, 1008, 924, 996, 979, 997, 1007, 1019, 982, 1017, 1051, 1071, 1010, 1060, 924, 989, 1008, 1035, 992, 1037, 995, 1075, 973, 1011, 955, 1002, 1002, 1005, 1042, 960, 1025, 1019, 960, 986, 990]
# ...

# %% [markdown]
# ### Make a plot of `counts` vs `timestamps`

# %%
fig, ax = plt.subplots(figsize=(10, 6))

# Your code here
plt.plot(timestamps, counts)

# %% [markdown]
# ### Make the same plot as above but normalise the `counts` data to the mean counts
#
# Find the mean value of the `counts` and save it to a variable named `mean_counts`.
#
# Divide the `counts` by the mean value and save it to a variable called `normalised_counts`.
#
# Plot `normalised_counts` vs `timestamps`.

# %%
fig, ax = plt.subplots(figsize=(10, 6))


# Your code here

mean_counts = np.mean(counts)
normalised_counts = counts / mean_counts
plt.plot(timestamps, normalised_counts)
